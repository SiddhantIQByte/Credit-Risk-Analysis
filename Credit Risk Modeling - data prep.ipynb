# %% [markdown]
# #### Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import Dataset

# %%
dfA = pd.read_csv('data.csv')
# Out:
# /tmp/ipykernel_4384/3993206278.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfA = pd.read_csv('data.csv')

# %%
df= dfA.copy()

# %%
df
# Out:
#         Unnamed: 0       id  member_id  loan_amnt  funded_amnt  \
# 0                0  1077501    1296599       5000         5000
# 1                1  1077430    1314167       2500         2500
# 2                2  1077175    1313524       2400         2400
# 3                3  1076863    1277178      10000        10000
# 4                4  1075358    1311748       3000         3000
# ...            ...      ...        ...        ...          ...
# 466280      466280  8598660    1440975      18400        18400
# 466281      466281  9684700   11536848      22000        22000
# 466282      466282  9584776   11436914      20700        20700
# 466283      466283  9604874   11457002       2000         2000
# 466284      466284  9199665   11061576      10000        10000
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 0                4975.0   36 months     10.65       162.87     B  ...
# ...

# %%
pd.options.display.max_columns = None

# %%
df.head(3)
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
#
#          term  int_rate  installment grade sub_grade emp_title emp_length  \
# 0   36 months     10.65       162.87     B        B2       NaN  10+ years
# 1   60 months     15.27        59.83     C        C4     Ryder   < 1 year
# 2   36 months     15.96        84.33     C        C5       NaN  10+ years
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT     24000.0            Verified  Dec-11   Fully Paid
# 1           RENT     30000.0     Source Verified  Dec-11  Charged Off
# 2           RENT     12252.0        Not Verified  Dec-11   Fully Paid
#
#   pymnt_plan                                                url  \
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'member_id', 'loan_amnt', 'funded_amnt',
#        'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
#        'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
# ...

# %%
# df['emp_length'].fillna('0').astype(str)

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
df['emp_length_int'] = df['emp_length'].str.replace(' \+ years', '0')
df['emp_length_int'] = df['emp_length_int'].str.replace('< 1 year', str(0))
df['emp_length_int'] = df['emp_length_int'].str.replace('n/a',  str(0))
df['emp_length_int'] = df['emp_length_int'].str.replace(' years', '')
df['emp_length_int'] = df['emp_length_int'].str.replace(' year', '')

# %%
df['emp_length_int'].unique()
# Out:
# array(['10+', '0', '1', '3', '8', '9', '4', '5', '6', '2', '7', nan],
#       dtype=object)

# %%
df['emp_length_int'].fillna('0').astype(str)
# Out:
# 0         10+
# 1           0
# 2         10+
# 3         10+
# 4           1
#          ...
# 466280      4
# 466281    10+
# 466282      7
# 466283      3
# 466284    10+
# Name: emp_length_int, Length: 466285, dtype: object

# %%
df['emp_length_int'].unique()
# Out:
# array(['10+', '0', '1', '3', '8', '9', '4', '5', '6', '2', '7', nan],
#       dtype=object)

# %%
df['emp_length_int'] = df['emp_length_int'].str.replace('+', '')

# %%
df['emp_length_int'].unique()
# Out:
# array(['10', '0', '1', '3', '8', '9', '4', '5', '6', '2', '7', nan],
#       dtype=object)

# %%
type(df['emp_length_int'][0])
# Out:
# str

# %%
df['emp_length_int']= pd.to_numeric(df['emp_length_int'])

# %%
type(df['emp_length_int'][0])
# Out:
# numpy.float64

# %%
df['emp_length_int'].unique()
# Out:
# array([10.,  0.,  1.,  3.,  8.,  9.,  4.,  5.,  6.,  2.,  7., nan])

# %%
df['earliest_cr_line']
# Out:
# 0         Jan-85
# 1         Apr-99
# 2         Nov-01
# 3         Feb-96
# 4         Jan-96
#            ...
# 466280    Apr-03
# 466281    Jun-97
# 466282    Dec-01
# 466283    Feb-03
# 466284    Feb-00
# Name: earliest_cr_line, Length: 466285, dtype: object

# %%
df['earliest_cr_line_date'] = pd.to_datetime(df['earliest_cr_line'], format = '%b-%y')
# Extracts the date and the time from a string variable that is in a given format.

# %%
type(df['earliest_cr_line'][0])
# Out:
# str

# %%
(pd.to_datetime('2024-01-06') - df['earliest_cr_line_date'])
# Out:
# 0        14249 days
# 1         9046 days
# 2         8101 days
# 3        10201 days
# 4        10232 days
#             ...
# 466280    7585 days
# 466281    9715 days
# 466282    8071 days
# 466283    7644 days
# 466284    8740 days
# Name: earliest_cr_line_date, Length: 466285, dtype: timedelta64[ns]

# %%
# Assume we are now in December 2017
df['mths_since_earliest_cr_line'] = round(pd.to_numeric((pd.to_datetime('2024-01-06') - df['earliest_cr_line_date'])*(1/30) /np.timedelta64(1, 'D')))
# We save the result in a new variable.

# %%
df.head()
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
#
#          term  int_rate  installment grade sub_grade  \
# 0   36 months     10.65       162.87     B        B2
# 1   60 months     15.27        59.83     C        C4
# 2   36 months     15.96        84.33     C        C5
# 3   36 months     13.49       339.31     C        C1
# 4   60 months     12.69        67.79     B        B5
#
#                   emp_title emp_length home_ownership  annual_inc  \
# 0                       NaN  10+ years           RENT     24000.0
# ...

# %%
df['mths_since_earliest_cr_line'].describe() # the min value is in negative
# Out:
# count    466256.000000
# mean        317.208283
# std          95.343675
# min        -547.000000
# 25%         260.000000
# 50%         303.000000
# 75%         363.000000
# max         670.000000
# Name: mths_since_earliest_cr_line, dtype: float64

# %%
df.loc[: , ['earliest_cr_line', 'earliest_cr_line_date', 'mths_since_earliest_cr_line']][df['mths_since_earliest_cr_line'] < 0]
# We take three columns from the dataframe. Then, we display them only for the rows where a variable has negative value.
# Out:
#        earliest_cr_line earliest_cr_line_date  mths_since_earliest_cr_line
# 1580             Sep-62            2062-09-01                       -471.0
# 1770             Sep-68            2068-09-01                       -544.0
# 2799             Sep-64            2064-09-01                       -495.0
# 3282             Sep-67            2067-09-01                       -531.0
# 3359             Feb-65            2065-02-01                       -500.0
# ...                 ...                   ...                          ...
# 464003           Jan-68            2068-01-01                       -536.0
# 464260           Jul-66            2066-07-01                       -517.0
# 465100           Oct-67            2067-10-01                       -532.0
# 465500           Sep-67            2067-09-01                       -531.0
# 465655           Jan-56            2056-01-01                       -389.0
#
# [1169 rows x 3 columns]

# %%
df.loc[: , ['earliest_cr_line', 'earliest_cr_line_date', 'mths_since_earliest_cr_line']][df['mths_since_earliest_cr_line'] ==0]
# Out:
# Empty DataFrame
# Columns: [earliest_cr_line, earliest_cr_line_date, mths_since_earliest_cr_line]
# Index: []

# %%
df['mths_since_earliest_cr_line'][df['mths_since_earliest_cr_line'] < 0] = df['mths_since_earliest_cr_line'].max()
# We set the rows that had negative differences to the maximum value.
# Out:
# /tmp/ipykernel_4384/2309340626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mths_since_earliest_cr_line'][df['mths_since_earliest_cr_line'] < 0] = df['mths_since_earliest_cr_line'].max()

# %%
min(df['mths_since_earliest_cr_line'])
# Out:
# 148.0

# %%
df.isnull()
# Out:
#         Unnamed: 0     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0            False  False      False      False        False            False
# 1            False  False      False      False        False            False
# 2            False  False      False      False        False            False
# 3            False  False      False      False        False            False
# 4            False  False      False      False        False            False
# ...            ...    ...        ...        ...          ...              ...
# 466280       False  False      False      False        False            False
# 466281       False  False      False      False        False            False
# 466282       False  False      False      False        False            False
# 466283       False  False      False      False        False            False
# 466284       False  False      False      False        False            False
#
# ...

# %%
pd.options.display.max_rows = None
# Sets the pandas dataframe options to display all columns/ rows.
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       27588
# emp_length                      21008
# home_ownership                      0
# annual_inc                          4
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# url                                 0
# desc                           340304
# purpose                             0
# title                              21
# zip_code                            0
# addr_state                          0
# ...

# %%
pd.options.display.max_rows = 100
# Sets the pandas dataframe options to display 100 columns/ rows.

# %%
# 'Total revolving high credit/ credit limit', so it makes sense that the missing values are equal to funded_amnt.
df['total_rev_hi_lim'].fillna(df['funded_amnt'], inplace=True)
# We fill the missing values with the values of another variable.

# %%
df['total_rev_hi_lim'].isnull().sum()
# Out:
# 0
